# %% [markdown]
# <a href="https://colab.research.google.com/github/drpsy/MEC_taskOffloading/blob/master/mec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir mec
# %cd mec

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e83db561-3a13-4dc3-b0dc-86def2225c8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e83db561-3a13-4dc3-b0dc-86def2225c8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip Deep-Q-learning-for-mobile-edge-computing-main.zip
# Out:
# Archive:  Deep-Q-learning-for-mobile-edge-computing-main.zip
#    creating: Deep-Q-learning-for-mobile-edge-computing-main/__pycache__/
#   inflating: Deep-Q-learning-for-mobile-edge-computing-main/__pycache__/fog_env.cpython-310.pyc
#   inflating: Deep-Q-learning-for-mobile-edge-computing-main/__pycache__/fog_env.cpython-311.pyc
#   inflating: Deep-Q-learning-for-mobile-edge-computing-main/__pycache__/RL_brain.cpython-310.pyc
#   inflating: Deep-Q-learning-for-mobile-edge-computing-main/__pycache__/RL_brain.cpython-311.pyc
#   inflating: Deep-Q-learning-for-mobile-edge-computing-main/fog_env.py
#   inflating: Deep-Q-learning-for-mobile-edge-computing-main/LICENSE
#   inflating: Deep-Q-learning-for-mobile-edge-computing-main/README.md
#   inflating: Deep-Q-learning-for-mobile-edge-computing-main/RL_brain.py
#   inflating: Deep-Q-learning-for-mobile-edge-computing-main/train.py

# %%
# %cd Deep-Q-learning-for-mobile-edge-computing-main
# Out:
# /content/mec/Deep-Q-learning-for-mobile-edge-computing-main

# %%
import RL_brain
import fog_env

# %%
# %run train.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /content/mec/Deep-Q-learning-for-mobile-edge-computing-main/RL_brain.py:83: UserWarning: `tf.nn.rnn_cell.BasicLSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   lstm_dnn = tf.compat.v1.nn.rnn_cell.BasicLSTMCell(n_lstm)
# WARNING:tensorflow:From /content/mec/Deep-Q-learning-for-mobile-edge-computing-main/RL_brain.py:85: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# ...
